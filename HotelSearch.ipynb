# %%
import pandas as pd
import numpy as np
import random
from catboost import CatBoostRanker, Pool, MetricVisualizer
from copy import deepcopy

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
HotelSearch_orig=pd.read_csv("/Users/sureshvadakath/Documents/Datasets/SearchRanking/HotelSearch_train.csv")

# %%
HotelSearch_orig.dtypes

#print(HotelSearch_orig['booking_bool'].unique())
HotelSearch_orig["date_time"] = pd.to_datetime(HotelSearch_orig["date_time"],infer_datetime_format=True)
HotelSearch_orig["target"] = HotelSearch_orig.apply(get_target,axis=1)

HotelSearch_orig.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9917530 entries, 0 to 9917529
# Data columns (total 55 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   srch_id                      int64
#  1   date_time                    datetime64[ns]
#  2   site_id                      int64
#  3   visitor_location_country_id  int64
#  4   visitor_hist_starrating      float64
#  5   visitor_hist_adr_usd         float64
#  6   prop_country_id              int64
#  7   prop_id                      int64
#  8   prop_starrating              int64
#  9   prop_review_score            float64
#  10  prop_brand_bool              int64
#  11  prop_location_score1         float64
#  12  prop_location_score2         float64
#  13  prop_log_historical_price    float64
#  14  position                     int64
#  15  price_usd                    float64
#  16  promotion_flag               int64
#  17  srch_destination_id          int64
#  18  srch_length_of_stay          int64
#  19  srch_booking_window          int64
#  20  srch_adults_count            int64
#  21  srch_children_count          int64
#  22  srch_room_count              int64
#  23  srch_saturday_night_bool     int64
#  24  srch_query_affinity_score    float64
#  25  orig_destination_distance    float64
#  26  random_bool                  int64
#  27  comp1_rate                   float64
#  28  comp1_inv                    float64
#  29  comp1_rate_percent_diff      float64
#  30  comp2_rate                   float64
#  31  comp2_inv                    float64
#  32  comp2_rate_percent_diff      float64
#  33  comp3_rate                   float64
#  34  comp3_inv                    float64
#  35  comp3_rate_percent_diff      float64
#  36  comp4_rate                   float64
#  37  comp4_inv                    float64
#  38  comp4_rate_percent_diff      float64
#  39  comp5_rate                   float64
#  40  comp5_inv                    float64
#  41  comp5_rate_percent_diff      float64
#  42  comp6_rate                   float64
#  43  comp6_inv                    float64
#  44  comp6_rate_percent_diff      float64
#  45  comp7_rate                   float64
#  46  comp7_inv                    float64
#  47  comp7_rate_percent_diff      float64
#  48  comp8_rate                   float64
#  49  comp8_inv                    float64
#  50  comp8_rate_percent_diff      float64
#  51  click_bool                   int64
#  52  gross_bookings_usd           float64
#  53  booking_bool                 int64
#  54  target                       int64
# dtypes: datetime64[ns](1), float64(34), int64(20)
# memory usage: 4.1 GB

# %%
HotelSearch_all=HotelSearch_orig.dropna(axis=1,how="all")
HotelSearch_all.shape
# Out:
# (9917530, 55)

# %%
All_Searches=HotelSearch_all["srch_id"].unique().tolist()
training_sample_list = random.sample(All_Searches, int(len(All_Searches)*.01))
print(len(All_Searches))
print(len(training_sample_list))
test_sample_list_temp=set(All_Searches) - set(training_sample_list)
test_sample_list = random.sample(test_sample_list_temp, int(len(test_sample_list_temp)*.015))
print(len(test_sample_list_temp))
print(len(test_sample_list))
#training_searches_array = np.array(training_sample_list)
#test_searches_array = np.array(test_sample_list)
# Out:
# 399344
# 3993
# 395351
# 5930
# /var/folders/kc/v7s5qpm17l14gx5297w1_6pw0000gn/T/ipykernel_10151/1782490068.py:6: DeprecationWarning: Sampling from a set deprecated
# since Python 3.9 and will be removed in a subsequent version.
#   test_sample_list = random.sample(test_sample_list_temp, int(len(test_sample_list_temp)*.015))

# %%
#HotelSearch_train = HotelSearch_all.groupby('srch_id').filter(lambda x: x["srch_id"].values[0] in sampled_searches)
HotelSearch_train_temp = HotelSearch_all[HotelSearch_all['srch_id'].isin(training_sample_list)]
# Not in Test:  position, click_bool, gross_bookings_usd, nor booking_bool
HotelSearch_test_temp = HotelSearch_all[HotelSearch_all['srch_id'].isin(test_sample_list)]
print(HotelSearch_train_temp.shape)
print(HotelSearch_test_temp.shape)
HotelSearch_train_temp.to_csv('./data/HotelSearch_train_sampled.csv')
HotelSearch_test_temp.to_csv('./data/HotelSearch_test_sampled.csv')
# Out:
# (99686, 55)
# (147022, 55)

# %%
def get_target(row):
    """
    0=not clicked at all, 1=clicked but not booked, 2=booked
    """
#     if row.booking_bool>0:
#         return 2
#     if row.click_bool>0 :
#         return 1
#     return 0

    if row.booking_bool>0:
        return 1
    return 0

def featurize_df(df:pd.DataFrame) ->pd.DataFrame:
    """
    Extract more features
    """
    df["weekday"] = df["date_time"].dt.weekday
    df["week_of_year"] = df["date_time"].dt.isocalendar().week

    df["hour"] = df["date_time"].dt.hour
    df["minute"] = df["date_time"].dt.minute
    ## total time elapsed - allows model to learn continous trend over time to a degree
    df["time_epoch"] = df["date_time"].astype('int64')//1e9
    ## if we were looking at fraud: df["seconds"] = df.timestamp.dt.second
    df["early_night"] = ((df["hour"]>19) | (df["hour"]<3)) # no added value from feature
    
    df["nans_count"] = df.isna().sum(axis=1)
    
    ## we won't make any time series features for now
    ## We could add time series features per property/hotel. We'd need to check for unaries, and to add a shift/offset dependant on forecast horizon

    return df

# %%
HotelSearch_train=pd.read_csv("./data/HotelSearch_train_sampled.csv")
HotelSearch_test=pd.read_csv("./data/HotelSearch_test_sampled.csv")



#print(HotelSearch_orig['booking_bool'].unique())
HotelSearch_train["date_time"] = pd.to_datetime(HotelSearch_train["date_time"],infer_datetime_format=True)
HotelSearch_train["target"] = HotelSearch_train.apply(get_target,axis=1)

HotelSearch_test["date_time"] = pd.to_datetime(HotelSearch_test["date_time"],infer_datetime_format=True)
HotelSearch_test["target"] = HotelSearch_test.apply(get_target,axis=1)

HotelSearch_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99686 entries, 0 to 99685
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   99686 non-null  int64
#  1   srch_id                      99686 non-null  int64
#  2   date_time                    99686 non-null  datetime64[ns]
#  3   site_id                      99686 non-null  int64
#  4   visitor_location_country_id  99686 non-null  int64
#  5   visitor_hist_starrating      4529 non-null   float64
#  6   visitor_hist_adr_usd         4534 non-null   float64
#  7   prop_country_id              99686 non-null  int64
#  8   prop_id                      99686 non-null  int64
#  9   prop_starrating              99686 non-null  int64
#  10  prop_review_score            99512 non-null  float64
#  11  prop_brand_bool              99686 non-null  int64
#  12  prop_location_score1         99686 non-null  float64
#  13  prop_location_score2         77299 non-null  float64
#  14  prop_log_historical_price    99686 non-null  float64
#  15  position                     99686 non-null  int64
#  16  price_usd                    99686 non-null  float64
#  17  promotion_flag               99686 non-null  int64
#  18  srch_destination_id          99686 non-null  int64
#  19  srch_length_of_stay          99686 non-null  int64
#  20  srch_booking_window          99686 non-null  int64
#  21  srch_adults_count            99686 non-null  int64
#  22  srch_children_count          99686 non-null  int64
#  23  srch_room_count              99686 non-null  int64
#  24  srch_saturday_night_bool     99686 non-null  int64
#  25  srch_query_affinity_score    5278 non-null   float64
#  26  orig_destination_distance    67415 non-null  float64
#  27  random_bool                  99686 non-null  int64
#  28  comp1_rate                   2455 non-null   float64
#  29  comp1_inv                    2648 non-null   float64
#  30  comp1_rate_percent_diff      1996 non-null   float64
#  31  comp2_rate                   39750 non-null  float64
#  32  comp2_inv                    41822 non-null  float64
#  33  comp2_rate_percent_diff      10975 non-null  float64
#  34  comp3_rate                   29799 non-null  float64
#  35  comp3_inv                    32052 non-null  float64
#  36  comp3_rate_percent_diff      9407 non-null   float64
#  37  comp4_rate                   6447 non-null   float64
#  38  comp4_inv                    7251 non-null   float64
#  39  comp4_rate_percent_diff      2770 non-null   float64
#  40  comp5_rate                   44492 non-null  float64
#  41  comp5_inv                    47446 non-null  float64
#  42  comp5_rate_percent_diff      16706 non-null  float64
#  43  comp6_rate                   4799 non-null   float64
#  44  comp6_inv                    5215 non-null   float64
#  45  comp6_rate_percent_diff      1942 non-null   float64
#  46  comp7_rate                   6509 non-null   float64
#  47  comp7_inv                    7310 non-null   float64
#  48  comp7_rate_percent_diff      2885 non-null   float64
#  49  comp8_rate                   38151 non-null  float64
#  50  comp8_inv                    39717 non-null  float64
#  51  comp8_rate_percent_diff      12181 non-null  float64
#  52  click_bool                   99686 non-null  int64
#  53  gross_bookings_usd           2801 non-null   float64
#  54  booking_bool                 99686 non-null  int64
#  55  target                       99686 non-null  int64
# dtypes: datetime64[ns](1), float64(34), int64(21)
# memory usage: 42.6 MB

# %%
drop_cols=[]
drop_unary_cols = [c for c in list(HotelSearch_train)
    if HotelSearch_train[c].nunique(dropna=False) <= 1]
drop_unary_cols
target_cols = ["gross_bookings_usd","click_bool","booking_bool"] # leaky column, and original target columns
drop_cols.extend(drop_unary_cols)
drop_cols.extend(target_cols) 

HotelSearch_train = HotelSearch_train.drop(columns=drop_cols,errors="ignore")
HotelSearch_test  = HotelSearch_test.drop(columns=drop_cols,errors="ignore")
print(HotelSearch_train.shape)
print(HotelSearch_test.shape)
# Out:
# (99686, 53)
# (147022, 53)

# %%
HotelSearch_train = featurize_df(HotelSearch_train)
HotelSearch_test = featurize_df(HotelSearch_test)
HotelSearch_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147022 entries, 0 to 147021
# Data columns (total 60 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   Unnamed: 0                   147022 non-null  int64
#  1   srch_id                      147022 non-null  int64
#  2   date_time                    147022 non-null  datetime64[ns]
#  3   site_id                      147022 non-null  int64
#  4   visitor_location_country_id  147022 non-null  int64
#  5   visitor_hist_starrating      7506 non-null    float64
#  6   visitor_hist_adr_usd         7506 non-null    float64
#  7   prop_country_id              147022 non-null  int64
#  8   prop_id                      147022 non-null  int64
#  9   prop_starrating              147022 non-null  int64
#  10  prop_review_score            146813 non-null  float64
#  11  prop_brand_bool              147022 non-null  int64
#  12  prop_location_score1         147022 non-null  float64
#  13  prop_location_score2         114480 non-null  float64
#  14  prop_log_historical_price    147022 non-null  float64
#  15  position                     147022 non-null  int64
#  16  price_usd                    147022 non-null  float64
#  17  promotion_flag               147022 non-null  int64
#  18  srch_destination_id          147022 non-null  int64
#  19  srch_length_of_stay          147022 non-null  int64
#  20  srch_booking_window          147022 non-null  int64
#  21  srch_adults_count            147022 non-null  int64
#  22  srch_children_count          147022 non-null  int64
#  23  srch_room_count              147022 non-null  int64
#  24  srch_saturday_night_bool     147022 non-null  int64
#  25  srch_query_affinity_score    9159 non-null    float64
#  26  orig_destination_distance    97803 non-null   float64
#  27  random_bool                  147022 non-null  int64
#  28  comp1_rate                   3588 non-null    float64
#  29  comp1_inv                    3868 non-null    float64
#  30  comp1_rate_percent_diff      2704 non-null    float64
#  31  comp2_rate                   59450 non-null   float64
#  32  comp2_inv                    62435 non-null   float64
#  33  comp2_rate_percent_diff      16307 non-null   float64
#  34  comp3_rate                   44548 non-null   float64
#  35  comp3_inv                    48214 non-null   float64
#  36  comp3_rate_percent_diff      13773 non-null   float64
#  37  comp4_rate                   8971 non-null    float64
#  38  comp4_inv                    9972 non-null    float64
#  39  comp4_rate_percent_diff      3636 non-null    float64
#  40  comp5_rate                   66000 non-null   float64
#  41  comp5_inv                    70000 non-null   float64
#  42  comp5_rate_percent_diff      24834 non-null   float64
#  43  comp6_rate                   7061 non-null    float64
#  44  comp6_inv                    7699 non-null    float64
#  45  comp6_rate_percent_diff      2784 non-null    float64
#  46  comp7_rate                   9649 non-null    float64
#  47  comp7_inv                    10860 non-null   float64
#  48  comp7_rate_percent_diff      4370 non-null    float64
#  49  comp8_rate                   55935 non-null   float64
#  50  comp8_inv                    57941 non-null   float64
#  51  comp8_rate_percent_diff      17869 non-null   float64
#  52  target                       147022 non-null  int64
#  53  weekday                      147022 non-null  int64
#  54  week_of_year                 147022 non-null  UInt32
#  55  hour                         147022 non-null  int64
#  56  minute                       147022 non-null  int64
#  57  time_epoch                   147022 non-null  float64
#  58  early_night                  147022 non-null  bool
#  59  nans_count                   147022 non-null  int64
# dtypes: UInt32(1), bool(1), datetime64[ns](1), float64(34), int64(23)
# memory usage: 65.9 MB

# %%
HotelSearch_train.drop(['comp3_rate',
       'comp3_inv', 'comp3_rate_percent_diff', 'comp4_inv', 'comp5_rate',
       'comp5_inv', 'comp5_rate_percent_diff', 'comp8_rate', 'comp8_inv',
       'comp8_rate_percent_diff'],axis=1).groupby(HotelSearch_train["target"]>0).mean()
HotelSearch_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99686 entries, 0 to 99685
# Data columns (total 60 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   99686 non-null  int64
#  1   srch_id                      99686 non-null  int64
#  2   date_time                    99686 non-null  datetime64[ns]
#  3   site_id                      99686 non-null  int64
#  4   visitor_location_country_id  99686 non-null  int64
#  5   visitor_hist_starrating      4529 non-null   float64
#  6   visitor_hist_adr_usd         4534 non-null   float64
#  7   prop_country_id              99686 non-null  int64
#  8   prop_id                      99686 non-null  int64
#  9   prop_starrating              99686 non-null  int64
#  10  prop_review_score            99512 non-null  float64
#  11  prop_brand_bool              99686 non-null  int64
#  12  prop_location_score1         99686 non-null  float64
#  13  prop_location_score2         77299 non-null  float64
#  14  prop_log_historical_price    99686 non-null  float64
#  15  position                     99686 non-null  int64
#  16  price_usd                    99686 non-null  float64
#  17  promotion_flag               99686 non-null  int64
#  18  srch_destination_id          99686 non-null  int64
#  19  srch_length_of_stay          99686 non-null  int64
#  20  srch_booking_window          99686 non-null  int64
#  21  srch_adults_count            99686 non-null  int64
#  22  srch_children_count          99686 non-null  int64
#  23  srch_room_count              99686 non-null  int64
#  24  srch_saturday_night_bool     99686 non-null  int64
#  25  srch_query_affinity_score    5278 non-null   float64
#  26  orig_destination_distance    67415 non-null  float64
#  27  random_bool                  99686 non-null  int64
#  28  comp1_rate                   2455 non-null   float64
#  29  comp1_inv                    2648 non-null   float64
#  30  comp1_rate_percent_diff      1996 non-null   float64
#  31  comp2_rate                   39750 non-null  float64
#  32  comp2_inv                    41822 non-null  float64
#  33  comp2_rate_percent_diff      10975 non-null  float64
#  34  comp3_rate                   29799 non-null  float64
#  35  comp3_inv                    32052 non-null  float64
#  36  comp3_rate_percent_diff      9407 non-null   float64
#  37  comp4_rate                   6447 non-null   float64
#  38  comp4_inv                    7251 non-null   float64
#  39  comp4_rate_percent_diff      2770 non-null   float64
#  40  comp5_rate                   44492 non-null  float64
#  41  comp5_inv                    47446 non-null  float64
#  42  comp5_rate_percent_diff      16706 non-null  float64
#  43  comp6_rate                   4799 non-null   float64
#  44  comp6_inv                    5215 non-null   float64
#  45  comp6_rate_percent_diff      1942 non-null   float64
#  46  comp7_rate                   6509 non-null   float64
#  47  comp7_inv                    7310 non-null   float64
#  48  comp7_rate_percent_diff      2885 non-null   float64
#  49  comp8_rate                   38151 non-null  float64
#  50  comp8_inv                    39717 non-null  float64
#  51  comp8_rate_percent_diff      12181 non-null  float64
#  52  target                       99686 non-null  int64
#  53  weekday                      99686 non-null  int64
#  54  week_of_year                 99686 non-null  UInt32
#  55  hour                         99686 non-null  int64
#  56  minute                       99686 non-null  int64
#  57  time_epoch                   99686 non-null  float64
#  58  early_night                  99686 non-null  bool
#  59  nans_count                   99686 non-null  int64
# dtypes: UInt32(1), bool(1), datetime64[ns](1), float64(34), int64(23)
# memory usage: 44.7 MB

# %%
cutoff_id = HotelSearch_train["srch_id"].quantile(0.94) # 90/10 split

X_train_df=HotelSearch_train.loc[HotelSearch_train.srch_id< cutoff_id].drop(["target","date_time"],axis=1)
X_eval_df = HotelSearch_train.loc[HotelSearch_train.srch_id>= cutoff_id].drop(["target","date_time"],axis=1)
X_test_df=HotelSearch_test.drop(["target","date_time"],axis=1)

feature_cols=X_train_df.columns.tolist()
# X_train_df=HotelSearch_train.loc[HotelSearch_train.srch_id< cutoff_id]
# X_eval_df = HotelSearch_train.loc[HotelSearch_train.srch_id>= cutoff_id]

y_train_df = HotelSearch_train.loc[HotelSearch_train.srch_id< cutoff_id]["target"].astype(float)
y_eval_df = HotelSearch_train.loc[HotelSearch_train.srch_id>= cutoff_id]["target"].astype(float)
y_test_df = HotelSearch_test["target"].astype(float)

X_train = X_train_df.values
X_eval = X_eval_df.values
X_test= X_test_df.values
queries_train = X_train_df["srch_id"].values

y_train = y_train_df.values
y_eval = y_eval_df.values
y_test = y_test_df.values

queries_test = X_eval_df["srch_id"].values



max_relevance = float(np.max(y_train))
y_train /= max_relevance
y_eval /= max_relevance
y_train_df.value_counts()
# Out:
# 0.0    91066
# 1.0     2637
# Name: target, dtype: int64

# %%
print("mean relevancy train",round(y_train.mean(),4))
print("mean relevancy eval",round(y_eval.mean(),4))
print(y_eval_df.value_counts()) # check we have all 3 "labels" in subset
# Out:
# mean relevancy train 0.0281
# mean relevancy eval 0.0274
# 0.0    5819
# 1.0     164
# Name: target, dtype: int64

# %%
HotelSearch_train['target'].value_counts()
# Out:
# 0    96885
# 1     2801
# Name: target, dtype: int64

# %%
categorical_cols = ['prop_id',"srch_destination_id", "weekday"] # ,"week_of_year"

# %%
X_train_df.shape
# Out:
# (93703, 58)

# %%
#set(X_train.columns).symmetric_difference(set(HotelSearch_test.columns))
train_pool = Pool(data=X_train,
                  label = y_train,
#                  cat_features=categorical_cols,
                  group_id=queries_train
                 )

eval_pool = Pool(data=X_eval,
                  label = y_eval,
#                  cat_features=categorical_cols,
                  group_id=queries_test
                 )

# %%
default_parameters  = {
    'iterations': 2000,
    'custom_metric': ['NDCG', "AUC:type=Ranking",'PrecisionAt:top=10', 'RecallAt:top=10', 'MAP:top=10'], # , 'AverageGain:top=3'# 'QueryRMSE', "YetiLoss" (use with hints)
    'verbose': False,
    'random_seed': 42,
#     "task_type":"GPU",
#    "has_time":True,
    "metric_period":4,
    "save_snapshot":False,
    "use_best_model":True, # requires eval set to be set
} 

parameters = {}

# %%
def fit_model(loss_function, prediction_function, feature_cols,X_train,y_train,X_test,y_test,additional_params=None, train_pool=train_pool, test_pool=eval_pool):
    parameters = deepcopy(default_parameters)
    parameters['loss_function'] = loss_function
    parameters['train_dir'] = loss_function
    
    if additional_params is not None:
        parameters.update(additional_params)
    print("best results (train on train):") 
    print(parameters) 

    model = CatBoostRanker(**parameters)
    model.fit(train_pool, eval_set=test_pool, plot=True)
    print("best results (train on train):")
    print(model.get_best_score()["learn"])
    print("best results (on validation set):")
    print(model.get_best_score()["validation"])

#Training predictions
    y_train_predictions = prediction_function(model, X_train)
    training_predictions = pd.DataFrame(X_train,columns=feature_cols)
    training_predictions['ActualRelevancy'] = y_train
    training_predictions['PredictedRelevancy'] = y_train_predictions

    
#Test predictions
    y_test_predictions = prediction_function(model, X_test)
    test_predictions = pd.DataFrame(X_test,columns=feature_cols)
    test_predictions['ActualRelevancy'] = y_test
    test_predictions['PredictedRelevancy'] = y_test_predictions

#     print("(Default) Feature importance (on train pool)")
#     display(model.get_feature_importance(data=train_pool,prettified=True).head(15))
    
#     try:
#         print("SHAP features importance, on all data:")
#         explainer = shap.TreeExplainer(model)
#         shap_values = explainer.shap_values(pd.concat([X_train,X_eval]),
#                                             y=pd.concat([y_train,y_eval]))

#         # # summarize the effects of all the features
#         shap.summary_plot(shap_values, pd.concat([X_train,X_eval]))
#    finally:
    return model, training_predictions , test_predictions

# %%
def get_predicted_outcome(model, data):
    a=model.predict(data)
    print(a)
#    print(np.argmax(model.predict_proba(data), axis=1).astype(np.float32))
#    return np.argmax(model.predict_proba(data), axis=1).astype(np.float32)
    return model.predict(data)

# %%
#model = fit_model('RMSE', {'custom_metric': ['PrecisionAt:top=10', 'RecallAt:top=10', 'MAP:top=10']})
model,training_predictions, test_predictions = fit_model('QueryRMSE',get_predicted_outcome,feature_cols,X_train,y_train,X_test,y_test)
# Out:
# best results (train on train):
# {'iterations': 2000, 'custom_metric': ['NDCG', 'AUC:type=Ranking', 'PrecisionAt:top=10', 'RecallAt:top=10', 'MAP:top=10'], 'verbose': False, 'random_seed': 42, 'metric_period': 4, 'save_snapshot': False, 'use_best_model': True, 'loss_function': 'QueryRMSE', 'train_dir': 'QueryRMSE'}
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# best results (train on train):
# {'MAP:top=10': 0.38204436336918357, 'RecallAt:top=10': 0.9260441606810322, 'PrecisionAt:top=10': 0.06667321180489341, 'QueryRMSE': 0.14914949338384229}
# best results (on validation set):
# {'NDCG:type=Base': 0.6774996274669269, 'MAP:top=10': 0.2767161850495186, 'RecallAt:top=10': 0.8504273504273504, 'PrecisionAt:top=10': 0.05918633835300491, 'QueryRMSE': 0.1565270245258196, 'AUC:type=Ranking': 0.7590787537880535}
# [ 0.00169618  0.01707038  0.00070379 ... -0.01127752  0.08452764
#  -0.0180627 ]
# [-0.00452675 -0.00884071 -0.0091339  ...  0.11363267 -0.02296182
#  -0.00132029]

# %%
training_predictions["Predictedrank"] = training_predictions.groupby("srch_id")["PredictedRelevancy"].rank("dense", ascending=False)
training_predictions[["srch_id","site_id","position","ActualRelevancy","PredictedRelevancy","Predictedrank"]].sort_values(by=['srch_id','position'], ascending=True).head(200)
# Out:
#     srch_id site_id position  ActualRelevancy  PredictedRelevancy  \
# 7       136       5        1              0.0            0.009904
# 1       136       5        2              0.0            0.017070
# 22      136       5        3              0.0           -0.003318
# 16      136       5        4              0.0            0.031690
# 15      136       5        6              0.0            0.005223
# 12      136       5        7              0.0            0.016199
# 3       136       5        8              0.0            0.009082
# 10      136       5        9              0.0            0.016496
# 25      136       5       10              0.0            0.017783
# 11      136       5       12              0.0            0.005729
# 0       136       5       13              0.0            0.001696
# 24      136       5       14              0.0            0.006206
# 18      136       5       15              0.0            0.001660
# 14      136       5       16              0.0            0.005094
# 4       136       5       18              0.0           -0.007875
# 8       136       5       19              0.0            0.004522
# 6       136       5       20              0.0           -0.009984
# 5       136       5       21              0.0            0.007197
# 23      136       5       22              0.0           -0.004977
# 17      136       5       24              0.0           -0.002968
# 21      136       5       25              0.0           -0.006760
# 13      136       5       26              0.0           -0.009789
# 19      136       5       27              0.0           -0.003855
# 9       136       5       28              0.0           -0.004332
# 20      136       5       29              0.0           -0.013398
# 2       136       5       30              0.0            0.000704
# 37      773      24        1              0.0            0.121218
# 41      773      24        2              1.0            0.052812
# 39      773      24        3              0.0            0.020808
# 44      773      24        4              0.0           -0.000009
# 187    1327       5       29              0.0           -0.022901
# 171    1327       5       30              0.0           -0.034478
# 158    1327       5       31              0.0           -0.033288
# 175    1327       5       32              0.0           -0.026151
# 165    1327       5       33              0.0           -0.033197
# 184    1327       5       34              0.0           -0.033310
# 186    1327       5       35              0.0           -0.024644
# 157    1327       5       36              0.0           -0.016780
# 189    1338      14        1              0.0            0.060742
# 220    1338      14        2              0.0            0.015115
# 196    1338      14        3              0.0            0.021218
# 201    1338      14        4              0.0           -0.002539
# 195    1338      14        6              0.0            0.007665
# 192    1338      14        7              0.0            0.010433
# 199    1338      14        8              0.0            0.012330
# 208    1338      14        9              0.0           -0.003312
# 204    1338      14       10              0.0            0.009154
# 207    1338      14       12              0.0            0.011806
# 198    1338      14       13              0.0            0.004382
#
#      Predictedrank
# 7              6.0
# 1              3.0
# 22            18.0
# 16             1.0
# 15            11.0
# 12             5.0
# 3              7.0
# 10             4.0
# 25             2.0
# 11            10.0
# 0             14.0
# 24             9.0
# 18            15.0
# 14            12.0
# 4             23.0
# 8             13.0
# 6             25.0
# 5              8.0
# 23            21.0
# 17            17.0
# 21            22.0
# 13            24.0
# 19            19.0
# 9             20.0
# 20            26.0
# 2             16.0
# 37             1.0
# 41             2.0
# 39             3.0
# 44             8.0
# 45             5.0
# 51             6.0
# 26             4.0
# 50             7.0
# 40            10.0
# 29            15.0
# 46             9.0
# 53            16.0
# 52            25.0
# 49            24.0
# 33            14.0
# 34            12.0
# 43            26.0
# 32            18.0
# 30            28.0
# 38            23.0
# 48            27.0
# 31            17.0
# 36            11.0
# 47            19.0
# 35            20.0
# 28            21.0
# 42            22.0
# 27            13.0
# 63             1.0
# 66             2.0
# 56             3.0
# 68             4.0
# 61             7.0
# 70             5.0
# 58             6.0
# 62            10.0
# 69            11.0
# 54             9.0
# 59             8.0
# 60            12.0
# 65            14.0
# 64            13.0
# 57            15.0
# 67            16.0
# 55            17.0
# 75             1.0
# 80             2.0
# 78             4.0
# 89             5.0
# 73             3.0
# 81             6.0
# 79             9.0
# 92            16.0
# 97            23.0
# 94            22.0
# 84            14.0
# 96            25.0
# 91             7.0
# 93            26.0
# 77            27.0
# 71            17.0
# 72            18.0
# 88             8.0
# 90            12.0
# 82            10.0
# 87            24.0
# 76            20.0
# 98            13.0
# 74            11.0
# 86            21.0
# 85            19.0
# 95            15.0
# 83            28.0
# 116            1.0
# 115            2.0
# 114            3.0
# 105            4.0
# 107            5.0
# 121            7.0
# 122            6.0
# 99            18.0
# 113           14.0
# 118           15.0
# 103           23.0
# 108            8.0
# 102           22.0
# 106           13.0
# 119           17.0
# 100           26.0
# 109           24.0
# 117           12.0
# 111           20.0
# 104           19.0
# 112           21.0
# 110           25.0
# 123            9.0
# 120           11.0
# 124           10.0
# 101           16.0
# 156            1.0
# 126            2.0
# 133            3.0
# 147            5.0
# 125            8.0
# 146            4.0
# 127            6.0
# 150           13.0
# 153           11.0
# 151           10.0
# 139           22.0
# 152            7.0
# 140           17.0
# 135           15.0
# 128           12.0
# 136           18.0
# 137           24.0
# 138           28.0
# 132           25.0
# 131           20.0
# 148           23.0
# 134           14.0
# 155           30.0
# 130           27.0
# 143           31.0
# 145           29.0
# 144           32.0
# 142            9.0
# 149           19.0
# 154           26.0
# 129           21.0
# 141           16.0
# 180            3.0
# 182            2.0
# 167            4.0
# 174           24.0
# 173            7.0
# 176            1.0
# 185            5.0
# 162           32.0
# 159           27.0
# 170            6.0
# 169           14.0
# 177           12.0
# 168           13.0
# 166           11.0
# 172           20.0
# 183            8.0
# 179           25.0
# 181           21.0
# 160           16.0
# 163           23.0
# 164           22.0
# 188           31.0
# 161           15.0
# 178            9.0
# 187           17.0
# 171           30.0
# 158           28.0
# 175           19.0
# 165           26.0
# 184           29.0
# 186           18.0
# 157           10.0
# 189            1.0
# 220            8.0
# 196            2.0
# 201           28.0
# 195           18.0
# 192           13.0
# 199           11.0
# 208           29.0
# 204           15.0
# 207           12.0
# 198           21.0

# %%
test_predictions["Predictedrank"] = test_predictions.groupby("srch_id")["PredictedRelevancy"].rank("dense", ascending=False)
test_predictions[["srch_id","site_id","position","ActualRelevancy","PredictedRelevancy","Predictedrank"]].sort_values(by=['srch_id','position'], ascending=True).head(200)
# Out:
#     srch_id site_id position  ActualRelevancy  PredictedRelevancy  \
# 21        1      12        1              0.0            0.069204
# 13        1      12        2              0.0           -0.008215
# 8         1      12        3              0.0            0.013211
# 4         1      12        4              0.0            0.013235
# 19        1      12        6              0.0           -0.007793
# 5         1      12        7              0.0            0.003575
# 18        1      12        8              0.0            0.017713
# 9         1      12       10              0.0           -0.005091
# 23        1      12       12              0.0           -0.002397
# 12        1      12       13              1.0           -0.005133
# 14        1      12       15              0.0           -0.004208
# 6         1      12       18              0.0           -0.006539
# 11        1      12       19              0.0           -0.005643
# 10        1      12       20              0.0           -0.012782
# 2         1      12       21              0.0           -0.009134
# 16        1      12       23              0.0           -0.001087
# 24        1      12       24              0.0           -0.009740
# 1         1      12       26              0.0           -0.008841
# 0         1      12       27              0.0           -0.004527
# 20        1      12       28              0.0           -0.001782
# 27        1      12       29              0.0           -0.012346
# 15        1      12       31              0.0           -0.013628
# 22        1      12       32              0.0           -0.014152
# 26        1      12       33              0.0           -0.012716
# 3         1      12       34              0.0           -0.026442
# 7         1      12       35              0.0           -0.013670
# 17        1      12       36              0.0           -0.012520
# 25        1      12       37              0.0           -0.012411
# 55       21      15        1              0.0            0.256309
# 37       21      15        2              0.0            0.160473
# 47       21      15        3              0.0            0.096284
# 44       21      15        4              1.0            0.069880
# 43       21      15        5              0.0            0.042267
# 54       21      15        6              0.0            0.049419
# 32       21      15        7              0.0            0.048446
# 48       21      15        8              0.0            0.018106
# 50       21      15        9              0.0            0.011125
# 45       21      15       11              0.0            0.016536
# 28       21      15       12              0.0           -0.018422
# 33       21      15       13              0.0            0.001962
# 35       21      15       14              0.0           -0.014401
# 46       21      15       15              0.0           -0.012063
# 29       21      15       17              0.0           -0.027477
# 52       21      15       18              0.0           -0.013201
# 30       21      15       19              0.0           -0.001793
# 53       21      15       20              0.0           -0.019532
# 41       21      15       21              0.0           -0.014077
