# %%
import pandas as pd
import numpy as np
import random
from catboost import CatBoostRanker, Pool, MetricVisualizer
from copy import deepcopy
###testing gitpush
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def get_target(row):
    """
    0=not clicked at all, 1=clicked but not booked, 2=booked
    """
#     if row.booking_bool>0:
#         return 2
#     if row.click_bool>0 :
#         return 1
#     return 0

    if row.booking_bool>0:
        return 1
    return 0

def featurize_df(df:pd.DataFrame) ->pd.DataFrame:
    """
    Extract more features
    """
    df["weekday"] = df["date_time"].dt.weekday
    df["week_of_year"] = df["date_time"].dt.isocalendar().week

    df["hour"] = df["date_time"].dt.hour
    df["minute"] = df["date_time"].dt.minute
    ## total time elapsed - allows model to learn continous trend over time to a degree
    df["time_epoch"] = df["date_time"].astype('int64')//1e9
    ## if we were looking at fraud: df["seconds"] = df.timestamp.dt.second
    df["early_night"] = ((df["hour"]>19) | (df["hour"]<3)) # no added value from feature
    
    df["nans_count"] = df.isna().sum(axis=1)
    
    ## we won't make any time series features for now
    ## We could add time series features per property/hotel. We'd need to check for unaries, and to add a shift/offset dependant on forecast horizon

    return df

# %%
HotelSearch_train=pd.read_csv("./data/HotelSearch_train_sampled.csv")
HotelSearch_test=pd.read_csv("./data/HotelSearch_test_sampled.csv")



#print(HotelSearch_orig['booking_bool'].unique())
HotelSearch_train["date_time"] = pd.to_datetime(HotelSearch_train["date_time"],infer_datetime_format=True)
HotelSearch_train["target"] = HotelSearch_train.apply(get_target,axis=1)

HotelSearch_test["date_time"] = pd.to_datetime(HotelSearch_test["date_time"],infer_datetime_format=True)
HotelSearch_test["target"] = HotelSearch_test.apply(get_target,axis=1)

HotelSearch_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99686 entries, 0 to 99685
# Data columns (total 56 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Unnamed: 0                   99686 non-null  int64
#  1   srch_id                      99686 non-null  int64
#  2   date_time                    99686 non-null  datetime64[ns]
#  3   site_id                      99686 non-null  int64
#  4   visitor_location_country_id  99686 non-null  int64
#  5   visitor_hist_starrating      4529 non-null   float64
#  6   visitor_hist_adr_usd         4534 non-null   float64
#  7   prop_country_id              99686 non-null  int64
#  8   prop_id                      99686 non-null  int64
#  9   prop_starrating              99686 non-null  int64
#  10  prop_review_score            99512 non-null  float64
#  11  prop_brand_bool              99686 non-null  int64
#  12  prop_location_score1         99686 non-null  float64
#  13  prop_location_score2         77299 non-null  float64
#  14  prop_log_historical_price    99686 non-null  float64
#  15  position                     99686 non-null  int64
#  16  price_usd                    99686 non-null  float64
#  17  promotion_flag               99686 non-null  int64
#  18  srch_destination_id          99686 non-null  int64
#  19  srch_length_of_stay          99686 non-null  int64
#  20  srch_booking_window          99686 non-null  int64
#  21  srch_adults_count            99686 non-null  int64
#  22  srch_children_count          99686 non-null  int64
#  23  srch_room_count              99686 non-null  int64
#  24  srch_saturday_night_bool     99686 non-null  int64
#  25  srch_query_affinity_score    5278 non-null   float64
#  26  orig_destination_distance    67415 non-null  float64
#  27  random_bool                  99686 non-null  int64
#  28  comp1_rate                   2455 non-null   float64
#  29  comp1_inv                    2648 non-null   float64
#  30  comp1_rate_percent_diff      1996 non-null   float64
#  31  comp2_rate                   39750 non-null  float64
#  32  comp2_inv                    41822 non-null  float64
#  33  comp2_rate_percent_diff      10975 non-null  float64
#  34  comp3_rate                   29799 non-null  float64
#  35  comp3_inv                    32052 non-null  float64
#  36  comp3_rate_percent_diff      9407 non-null   float64
#  37  comp4_rate                   6447 non-null   float64
#  38  comp4_inv                    7251 non-null   float64
#  39  comp4_rate_percent_diff      2770 non-null   float64
#  40  comp5_rate                   44492 non-null  float64
#  41  comp5_inv                    47446 non-null  float64
#  42  comp5_rate_percent_diff      16706 non-null  float64
#  43  comp6_rate                   4799 non-null   float64
#  44  comp6_inv                    5215 non-null   float64
#  45  comp6_rate_percent_diff      1942 non-null   float64
#  46  comp7_rate                   6509 non-null   float64
#  47  comp7_inv                    7310 non-null   float64
#  48  comp7_rate_percent_diff      2885 non-null   float64
#  49  comp8_rate                   38151 non-null  float64
#  50  comp8_inv                    39717 non-null  float64
#  51  comp8_rate_percent_diff      12181 non-null  float64
#  52  click_bool                   99686 non-null  int64
#  53  gross_bookings_usd           2801 non-null   float64
#  54  booking_bool                 99686 non-null  int64
#  55  target                       99686 non-null  int64
# dtypes: datetime64[ns](1), float64(34), int64(21)
# memory usage: 42.6 MB

# %%
drop_cols=[]
drop_unary_cols = [c for c in list(HotelSearch_train)
    if HotelSearch_train[c].nunique(dropna=False) <= 1]
drop_unary_cols
target_cols = ["gross_bookings_usd","click_bool","booking_bool","Unnamed: 0"] # leaky column, and original target columns
drop_cols.extend(drop_unary_cols)
drop_cols.extend(target_cols) 

HotelSearch_train = HotelSearch_train.drop(columns=drop_cols,errors="ignore")
HotelSearch_test  = HotelSearch_test.drop(columns=drop_cols,errors="ignore")
print(HotelSearch_train.shape)
print(HotelSearch_test.shape)
# Out:
# (99686, 52)
# (147022, 52)

# %%
HotelSearch_train = featurize_df(HotelSearch_train)
HotelSearch_test = featurize_df(HotelSearch_test)
HotelSearch_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147022 entries, 0 to 147021
# Data columns (total 59 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   srch_id                      147022 non-null  int64
#  1   date_time                    147022 non-null  datetime64[ns]
#  2   site_id                      147022 non-null  int64
#  3   visitor_location_country_id  147022 non-null  int64
#  4   visitor_hist_starrating      7506 non-null    float64
#  5   visitor_hist_adr_usd         7506 non-null    float64
#  6   prop_country_id              147022 non-null  int64
#  7   prop_id                      147022 non-null  int64
#  8   prop_starrating              147022 non-null  int64
#  9   prop_review_score            146813 non-null  float64
#  10  prop_brand_bool              147022 non-null  int64
#  11  prop_location_score1         147022 non-null  float64
#  12  prop_location_score2         114480 non-null  float64
#  13  prop_log_historical_price    147022 non-null  float64
#  14  position                     147022 non-null  int64
#  15  price_usd                    147022 non-null  float64
#  16  promotion_flag               147022 non-null  int64
#  17  srch_destination_id          147022 non-null  int64
#  18  srch_length_of_stay          147022 non-null  int64
#  19  srch_booking_window          147022 non-null  int64
#  20  srch_adults_count            147022 non-null  int64
#  21  srch_children_count          147022 non-null  int64
#  22  srch_room_count              147022 non-null  int64
#  23  srch_saturday_night_bool     147022 non-null  int64
#  24  srch_query_affinity_score    9159 non-null    float64
#  25  orig_destination_distance    97803 non-null   float64
#  26  random_bool                  147022 non-null  int64
#  27  comp1_rate                   3588 non-null    float64
#  28  comp1_inv                    3868 non-null    float64
#  29  comp1_rate_percent_diff      2704 non-null    float64
#  30  comp2_rate                   59450 non-null   float64
#  31  comp2_inv                    62435 non-null   float64
#  32  comp2_rate_percent_diff      16307 non-null   float64
#  33  comp3_rate                   44548 non-null   float64
#  34  comp3_inv                    48214 non-null   float64
#  35  comp3_rate_percent_diff      13773 non-null   float64
#  36  comp4_rate                   8971 non-null    float64
#  37  comp4_inv                    9972 non-null    float64
#  38  comp4_rate_percent_diff      3636 non-null    float64
#  39  comp5_rate                   66000 non-null   float64
#  40  comp5_inv                    70000 non-null   float64
#  41  comp5_rate_percent_diff      24834 non-null   float64
#  42  comp6_rate                   7061 non-null    float64
#  43  comp6_inv                    7699 non-null    float64
#  44  comp6_rate_percent_diff      2784 non-null    float64
#  45  comp7_rate                   9649 non-null    float64
#  46  comp7_inv                    10860 non-null   float64
#  47  comp7_rate_percent_diff      4370 non-null    float64
#  48  comp8_rate                   55935 non-null   float64
#  49  comp8_inv                    57941 non-null   float64
#  50  comp8_rate_percent_diff      17869 non-null   float64
#  51  target                       147022 non-null  int64
#  52  weekday                      147022 non-null  int64
#  53  week_of_year                 147022 non-null  UInt32
#  54  hour                         147022 non-null  int64
#  55  minute                       147022 non-null  int64
#  56  time_epoch                   147022 non-null  float64
#  57  early_night                  147022 non-null  bool
#  58  nans_count                   147022 non-null  int64
# dtypes: UInt32(1), bool(1), datetime64[ns](1), float64(34), int64(22)
# memory usage: 64.8 MB

# %%
HotelSearch_train.drop(['comp3_rate',
       'comp3_inv', 'comp3_rate_percent_diff', 'comp4_inv', 'comp5_rate',
       'comp5_inv', 'comp5_rate_percent_diff', 'comp8_rate', 'comp8_inv',
       'comp8_rate_percent_diff'],axis=1).groupby(HotelSearch_train["target"]>0).mean()
HotelSearch_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99686 entries, 0 to 99685
# Data columns (total 59 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   srch_id                      99686 non-null  int64
#  1   date_time                    99686 non-null  datetime64[ns]
#  2   site_id                      99686 non-null  int64
#  3   visitor_location_country_id  99686 non-null  int64
#  4   visitor_hist_starrating      4529 non-null   float64
#  5   visitor_hist_adr_usd         4534 non-null   float64
#  6   prop_country_id              99686 non-null  int64
#  7   prop_id                      99686 non-null  int64
#  8   prop_starrating              99686 non-null  int64
#  9   prop_review_score            99512 non-null  float64
#  10  prop_brand_bool              99686 non-null  int64
#  11  prop_location_score1         99686 non-null  float64
#  12  prop_location_score2         77299 non-null  float64
#  13  prop_log_historical_price    99686 non-null  float64
#  14  position                     99686 non-null  int64
#  15  price_usd                    99686 non-null  float64
#  16  promotion_flag               99686 non-null  int64
#  17  srch_destination_id          99686 non-null  int64
#  18  srch_length_of_stay          99686 non-null  int64
#  19  srch_booking_window          99686 non-null  int64
#  20  srch_adults_count            99686 non-null  int64
#  21  srch_children_count          99686 non-null  int64
#  22  srch_room_count              99686 non-null  int64
#  23  srch_saturday_night_bool     99686 non-null  int64
#  24  srch_query_affinity_score    5278 non-null   float64
#  25  orig_destination_distance    67415 non-null  float64
#  26  random_bool                  99686 non-null  int64
#  27  comp1_rate                   2455 non-null   float64
#  28  comp1_inv                    2648 non-null   float64
#  29  comp1_rate_percent_diff      1996 non-null   float64
#  30  comp2_rate                   39750 non-null  float64
#  31  comp2_inv                    41822 non-null  float64
#  32  comp2_rate_percent_diff      10975 non-null  float64
#  33  comp3_rate                   29799 non-null  float64
#  34  comp3_inv                    32052 non-null  float64
#  35  comp3_rate_percent_diff      9407 non-null   float64
#  36  comp4_rate                   6447 non-null   float64
#  37  comp4_inv                    7251 non-null   float64
#  38  comp4_rate_percent_diff      2770 non-null   float64
#  39  comp5_rate                   44492 non-null  float64
#  40  comp5_inv                    47446 non-null  float64
#  41  comp5_rate_percent_diff      16706 non-null  float64
#  42  comp6_rate                   4799 non-null   float64
#  43  comp6_inv                    5215 non-null   float64
#  44  comp6_rate_percent_diff      1942 non-null   float64
#  45  comp7_rate                   6509 non-null   float64
#  46  comp7_inv                    7310 non-null   float64
#  47  comp7_rate_percent_diff      2885 non-null   float64
#  48  comp8_rate                   38151 non-null  float64
#  49  comp8_inv                    39717 non-null  float64
#  50  comp8_rate_percent_diff      12181 non-null  float64
#  51  target                       99686 non-null  int64
#  52  weekday                      99686 non-null  int64
#  53  week_of_year                 99686 non-null  UInt32
#  54  hour                         99686 non-null  int64
#  55  minute                       99686 non-null  int64
#  56  time_epoch                   99686 non-null  float64
#  57  early_night                  99686 non-null  bool
#  58  nans_count                   99686 non-null  int64
# dtypes: UInt32(1), bool(1), datetime64[ns](1), float64(34), int64(22)
# memory usage: 43.9 MB

# %%
cutoff_id = HotelSearch_train["srch_id"].quantile(0.94) # 90/10 split

X_train_df=HotelSearch_train.loc[HotelSearch_train.srch_id< cutoff_id].drop(["target","date_time"],axis=1)
X_eval_df = HotelSearch_train.loc[HotelSearch_train.srch_id>= cutoff_id].drop(["target","date_time"],axis=1)
X_test_df=HotelSearch_test.drop(["target","date_time"],axis=1)

feature_cols=X_train_df.columns.tolist()
# X_train_df=HotelSearch_train.loc[HotelSearch_train.srch_id< cutoff_id]
# X_eval_df = HotelSearch_train.loc[HotelSearch_train.srch_id>= cutoff_id]

y_train_df = HotelSearch_train.loc[HotelSearch_train.srch_id< cutoff_id]["target"].astype(float)
y_eval_df = HotelSearch_train.loc[HotelSearch_train.srch_id>= cutoff_id]["target"].astype(float)
y_test_df = HotelSearch_test["target"].astype(float)

X_train = X_train_df.values
X_eval = X_eval_df.values
X_test= X_test_df.values
queries_train = X_train_df["srch_id"].values

y_train = y_train_df.values
y_eval = y_eval_df.values
y_test = y_test_df.values

queries_test = X_eval_df["srch_id"].values



max_relevance = float(np.max(y_train))
y_train /= max_relevance
y_eval /= max_relevance
y_train_df.value_counts()
# Out:
# 0.0    91066
# 1.0     2637
# Name: target, dtype: int64

# %%
print("mean relevancy train",round(y_train.mean(),4))
print("mean relevancy eval",round(y_eval.mean(),4))
print(y_eval_df.value_counts()) # check we have all 3 "labels" in subset
# Out:
# mean relevancy train 0.0281
# mean relevancy eval 0.0274
# 0.0    5819
# 1.0     164
# Name: target, dtype: int64

# %%
HotelSearch_train['target'].value_counts()
# Out:
# 0    96885
# 1     2801
# Name: target, dtype: int64

# %%
categorical_cols = ['prop_id',"srch_destination_id", "weekday"] # ,"week_of_year"

# %%
X_train_df.shape
# Out:
# (93703, 57)

# %%
#set(X_train.columns).symmetric_difference(set(HotelSearch_test.columns))
train_pool = Pool(data=X_train,
                  label = y_train,
#                  cat_features=categorical_cols,
                  group_id=queries_train
                 )

eval_pool = Pool(data=X_eval,
                  label = y_eval,
#                  cat_features=categorical_cols,
                  group_id=queries_test
                 )

# %%
default_parameters  = {
    'iterations': 2000,
    'custom_metric': ['NDCG', "AUC:type=Ranking",'PrecisionAt:top=10', 'RecallAt:top=10', 'MAP:top=10'], # , 'AverageGain:top=3'# 'QueryRMSE', "YetiLoss" (use with hints)
    'verbose': False,
    'random_seed': 42,
#     "task_type":"GPU",
#    "has_time":True,
    "metric_period":4,
    "save_snapshot":False,
    "use_best_model":True, # requires eval set to be set
} 

parameters = {}

# %%
def fit_model(loss_function, prediction_function, feature_cols,X_train,y_train,X_test,y_test,additional_params=None, train_pool=train_pool, test_pool=eval_pool):
    parameters = deepcopy(default_parameters)
    parameters['loss_function'] = loss_function
    parameters['train_dir'] = loss_function
    
    if additional_params is not None:
        parameters.update(additional_params)
    print("best results (train on train):") 
    print(parameters) 

    model = CatBoostRanker(**parameters)
    model.fit(train_pool, eval_set=test_pool, plot=True)
    print("best results (train on train):")
    print(model.get_best_score()["learn"])
    print("best results (on validation set):")
    print(model.get_best_score()["validation"])

#Training predictions
    y_train_predictions = prediction_function(model, X_train)
    training_predictions = pd.DataFrame(X_train,columns=feature_cols)
    training_predictions['ActualRelevancy'] = y_train
    training_predictions['PredictedRelevancy'] = y_train_predictions

    
#Test predictions
    y_test_predictions = prediction_function(model, X_test)
    test_predictions = pd.DataFrame(X_test,columns=feature_cols)
    test_predictions['ActualRelevancy'] = y_test
    test_predictions['PredictedRelevancy'] = y_test_predictions

#     print("(Default) Feature importance (on train pool)")
#     display(model.get_feature_importance(data=train_pool,prettified=True).head(15))
    
#     try:
#         print("SHAP features importance, on all data:")
#         explainer = shap.TreeExplainer(model)
#         shap_values = explainer.shap_values(pd.concat([X_train,X_eval]),
#                                             y=pd.concat([y_train,y_eval]))

#         # # summarize the effects of all the features
#         shap.summary_plot(shap_values, pd.concat([X_train,X_eval]))
#    finally:
    return model, training_predictions , test_predictions

# %%
def get_predicted_outcome(model, data):
    a=model.predict(data)
    print(a)
#    print(np.argmax(model.predict_proba(data), axis=1).astype(np.float32))
#    return np.argmax(model.predict_proba(data), axis=1).astype(np.float32)
    return model.predict(data)

# %%
#model = fit_model('RMSE', {'custom_metric': ['PrecisionAt:top=10', 'RecallAt:top=10', 'MAP:top=10']})
model,training_predictions, test_predictions = fit_model('QueryRMSE',get_predicted_outcome,feature_cols,X_train,y_train,X_test,y_test)
# Out:
# best results (train on train):
# {'iterations': 2000, 'custom_metric': ['NDCG', 'AUC:type=Ranking', 'PrecisionAt:top=10', 'RecallAt:top=10', 'MAP:top=10'], 'verbose': False, 'random_seed': 42, 'metric_period': 4, 'save_snapshot': False, 'use_best_model': True, 'loss_function': 'QueryRMSE', 'train_dir': 'QueryRMSE'}
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# best results (train on train):
# {'MAP:top=10': 0.38236180257329483, 'RecallAt:top=10': 0.9249800478850758, 'PrecisionAt:top=10': 0.06656680052529777, 'QueryRMSE': 0.14918552996004378}
# best results (on validation set):
# {'NDCG:type=Base': 0.6800902765555251, 'MAP:top=10': 0.28126780626780645, 'RecallAt:top=10': 0.8589743589743589, 'PrecisionAt:top=10': 0.06004103920770576, 'QueryRMSE': 0.1564466936684731, 'AUC:type=Ranking': 0.7595115244845523}
# [ 0.0017476   0.02538033 -0.00209554 ... -0.01348368  0.08537377
#  -0.01976081]
# [-0.00334009 -0.00754448 -0.00897748 ...  0.11640193 -0.02197127
#   0.00058178]

# %%
training_predictions["Predictedrank"] = training_predictions.groupby("srch_id")["PredictedRelevancy"].rank("dense", ascending=False)
training_predictions[["srch_id","site_id","position","ActualRelevancy","PredictedRelevancy","Predictedrank"]].sort_values(by=['srch_id','position'], ascending=True).head(200)
# Out:
#     srch_id site_id position  ActualRelevancy  PredictedRelevancy  \
# 7       136       5        1              0.0            0.018830
# 1       136       5        2              0.0            0.025380
# 22      136       5        3              0.0           -0.000375
# 16      136       5        4              0.0            0.027576
# 15      136       5        6              0.0            0.003533
# 12      136       5        7              0.0            0.015347
# 3       136       5        8              0.0            0.006195
# 10      136       5        9              0.0            0.014774
# 25      136       5       10              0.0            0.013670
# 11      136       5       12              0.0            0.004504
# 0       136       5       13              0.0            0.001748
# 24      136       5       14              0.0            0.004123
# 18      136       5       15              0.0            0.001723
# 14      136       5       16              0.0            0.004780
# 4       136       5       18              0.0           -0.007733
# 8       136       5       19              0.0            0.004743
# 6       136       5       20              0.0           -0.011277
# 5       136       5       21              0.0            0.006295
# 23      136       5       22              0.0           -0.005475
# 17      136       5       24              0.0           -0.006146
# 21      136       5       25              0.0           -0.006999
# 13      136       5       26              0.0           -0.009860
# 19      136       5       27              0.0           -0.005399
# 9       136       5       28              0.0           -0.006568
# 20      136       5       29              0.0           -0.014197
# 2       136       5       30              0.0           -0.002096
# 37      773      24        1              0.0            0.126503
# 41      773      24        2              1.0            0.056132
# 39      773      24        3              0.0            0.016875
# 44      773      24        4              0.0            0.001977
# 45      773      24        6              0.0            0.003043
# 51      773      24        7              0.0           -0.000058
# 26      773      24        8              0.0            0.017868
# 50      773      24        9              0.0           -0.000122
# 40      773      24       10              0.0           -0.008551
# 29      773      24       12              0.0           -0.012236
# 46      773      24       13              0.0           -0.004155
# 53      773      24       14              0.0           -0.016752
# 52      773      24       15              0.0           -0.029514
# 49      773      24       16              0.0           -0.025460
# 189    1338      14        1              0.0            0.066953
# 220    1338      14        2              0.0           -0.000535
# 196    1338      14        3              0.0            0.016069
# 201    1338      14        4              0.0            0.000639
# 195    1338      14        6              0.0            0.003356
# 192    1338      14        7              0.0            0.004624
# 199    1338      14        8              0.0            0.007164
# 208    1338      14        9              0.0           -0.003155
# 204    1338      14       10              0.0            0.005671
# 207    1338      14       12              0.0            0.011543
# 198    1338      14       13              0.0            0.000255
#
#      Predictedrank
# 7              3.0
# 1              2.0
# 22            16.0
# 16             1.0
# 15            13.0
# 12             4.0
# 3              8.0
# 10             5.0
# 25             6.0
# 11            11.0
# 0             14.0
# 24            12.0
# 18            15.0
# 14             9.0
# 4             23.0
# 8             10.0
# 6             25.0
# 5              7.0
# 23            19.0
# 17            20.0
# 21            22.0
# 13            24.0
# 19            18.0
# 9             21.0
# 20            26.0
# 2             17.0
# 37             1.0
# 41             2.0
# 39             4.0
# 44             6.0
# 45             5.0
# 51             7.0
# 26             3.0
# 50             8.0
# 40            11.0
# 29            15.0
# 46             9.0
# 53            16.0
# 52            25.0
# 49            22.0
# 33            13.0
# 34            12.0
# 43            27.0
# 32            18.0
# 30            28.0
# 38            24.0
# 48            26.0
# 31            17.0
# 36            10.0
# 47            19.0
# 35            21.0
# 28            20.0
# 42            23.0
# 27            14.0
# 63             1.0
# 66             2.0
# 56             4.0
# 68             3.0
# 61             7.0
# 70             5.0
# 58             6.0
# 62            10.0
# 69            12.0
# 54             9.0
# 59             8.0
# 60            13.0
# 65            14.0
# 64            11.0
# 57            16.0
# 67            15.0
# 55            17.0
# 75             1.0
# 80             2.0
# 78             3.0
# 89             4.0
# 73             5.0
# 81             6.0
# 79             9.0
# 92            15.0
# 97            18.0
# 94            20.0
# 84            13.0
# 96            24.0
# 91             7.0
# 93            25.0
# 77            27.0
# 71            17.0
# 72            19.0
# 88             8.0
# 90            12.0
# 82            10.0
# 87            26.0
# 76            23.0
# 98            14.0
# 74            11.0
# 86            22.0
# 85            21.0
# 95            16.0
# 83            28.0
# 116            1.0
# 115            2.0
# 114            3.0
# 105            4.0
# 107            5.0
# 121            6.0
# 122            8.0
# 99            17.0
# 113           24.0
# 118           14.0
# 103           26.0
# 108            7.0
# 102           19.0
# 106           16.0
# 119           12.0
# 100           25.0
# 109           22.0
# 117            9.0
# 111           15.0
# 104           20.0
# 112           23.0
# 110           21.0
# 123           10.0
# 120           11.0
# 124           13.0
# 101           18.0
# 156            1.0
# 126            2.0
# 133            3.0
# 147            4.0
# 125           10.0
# 146            5.0
# 127            6.0
# 150           14.0
# 153           12.0
# 151            9.0
# 139           18.0
# 152            7.0
# 140           15.0
# 135           28.0
# 128           11.0
# 136           16.0
# 137           19.0
# 138           27.0
# 132           22.0
# 131           17.0
# 148           26.0
# 134           13.0
# 155           30.0
# 130           23.0
# 143           31.0
# 145           24.0
# 144           32.0
# 142            8.0
# 149           20.0
# 154           25.0
# 129           21.0
# 141           29.0
# 180            2.0
# 182            3.0
# 167            5.0
# 174           29.0
# 173            4.0
# 176            1.0
# 185            6.0
# 162           27.0
# 159           26.0
# 170            7.0
# 169           10.0
# 177           11.0
# 168            8.0
# 166            9.0
# 172           18.0
# 183           12.0
# 179           30.0
# 181           21.0
# 160           14.0
# 163           20.0
# 164           23.0
# 188           28.0
# 161           15.0
# 178           16.0
# 187           22.0
# 171           19.0
# 158           25.0
# 175           17.0
# 165           32.0
# 184           31.0
# 186           24.0
# 157           13.0
# 189            1.0
# 220           23.0
# 196            3.0
# 201           19.0
# 195           17.0
# 192           16.0
# 199           11.0
# 208           28.0
# 204           14.0
# 207            8.0
# 198           20.0

# %%
test_predictions["Predictedrank"] = test_predictions.groupby("srch_id")["PredictedRelevancy"].rank("dense", ascending=False)
test_predictions[["srch_id","site_id","position","ActualRelevancy","PredictedRelevancy","Predictedrank"]].sort_values(by=['srch_id','position'], ascending=True).head(200)
# Out:
#     srch_id site_id position  ActualRelevancy  PredictedRelevancy  \
# 21        1      12        1              0.0            0.050316
# 13        1      12        2              0.0           -0.005692
# 8         1      12        3              0.0            0.014007
# 4         1      12        4              0.0            0.010704
# 19        1      12        6              0.0           -0.007345
# 5         1      12        7              0.0            0.003609
# 18        1      12        8              0.0            0.018543
# 9         1      12       10              0.0           -0.003469
# 23        1      12       12              0.0           -0.000435
# 12        1      12       13              1.0           -0.006016
# 14        1      12       15              0.0           -0.005419
# 6         1      12       18              0.0           -0.006698
# 11        1      12       19              0.0           -0.001911
# 10        1      12       20              0.0           -0.013364
# 2         1      12       21              0.0           -0.008977
# 16        1      12       23              0.0            0.000727
# 24        1      12       24              0.0           -0.009896
# 1         1      12       26              0.0           -0.007544
# 0         1      12       27              0.0           -0.003340
# 20        1      12       28              0.0           -0.002338
# 27        1      12       29              0.0           -0.012010
# 15        1      12       31              0.0           -0.012142
# 22        1      12       32              0.0           -0.010449
# 26        1      12       33              0.0           -0.012051
# 3         1      12       34              0.0           -0.023498
# 7         1      12       35              0.0           -0.013220
# 17        1      12       36              0.0           -0.012199
# 25        1      12       37              0.0           -0.010420
# 55       21      15        1              0.0            0.259542
# 37       21      15        2              0.0            0.152220
# 47       21      15        3              0.0            0.079755
# 44       21      15        4              1.0            0.062171
# 43       21      15        5              0.0            0.041814
# 54       21      15        6              0.0            0.047970
# 32       21      15        7              0.0            0.037440
# 48       21      15        8              0.0            0.018388
# 50       21      15        9              0.0            0.010892
# 45       21      15       11              0.0            0.017835
# 28       21      15       12              0.0           -0.015136
# 33       21      15       13              0.0            0.002406
# 35       21      15       14              0.0           -0.015634
# 46       21      15       15              0.0           -0.010094
# 29       21      15       17              0.0           -0.026874
# 52       21      15       18              0.0           -0.012922
# 30       21      15       19              0.0           -0.006637
# 53       21      15       20              0.0           -0.020536
# 41       21      15       21              0.0           -0.016214
# 56       21      15       23              0.0           -0.023956
# 40       21      15       24              0.0           -0.020464
# 51       21      15       25              0.0           -0.032665
# 31       21      15       26              0.0           -0.026378
# 36       21      15       27              0.0           -0.030842
# 49       21      15       28              0.0           -0.021400
# 0             10.0
# 20             9.0
# 27            22.0
# 15            24.0
# 22            21.0
# 26            23.0
# 3             28.0
# 7             26.0
# 17            25.0
# 25            20.0
# 55             1.0
# 37             2.0
# 47             3.0
# 44             4.0
# 43             6.0
# 54             5.0
# 32             7.0
# 48             8.0
# 50            10.0
# 45             9.0
# 28            15.0
# 33            11.0
# 35            16.0
# 46            13.0
# 29            24.0
# 52            14.0
# 30            12.0
# 53            19.0
# 41            17.0
# 56            21.0
# 40            18.0
# 51            29.0
# 31            23.0
# 36            27.0
# 49            20.0
# 34            26.0
# 38            28.0
# 42            25.0
# 39            22.0
# 64             1.0
# 66             2.0
# 75             3.0
# 60             4.0
# 72             6.0
# 59             5.0
# 61             8.0
# 67             9.0
# 68            10.0
# 77            21.0
# 78            13.0
# 58             7.0
# 73            12.0
# 76            14.0
# 69            15.0
# 74            18.0
# 80            17.0
# 71            23.0
# 65            16.0
# 79            22.0
# 57            20.0
# 62            11.0
# 63            24.0
# 70            19.0
# 104            1.0
# 100            2.0
# 93             3.0
# 109            4.0
# 105            5.0
# 96            11.0
# 88             7.0
# 86             6.0
# 111            8.0
# 108            9.0
# 97            14.0
# 81            23.0
# 89            10.0
# 90            17.0
# 110           15.0
# 85            13.0
# 82            21.0
# 92            12.0
# 87            16.0
# 102           22.0
# 101           20.0
# 99            18.0
# 106           26.0
# 94            29.0
# 103           19.0
# 91            28.0
# 83            24.0
# 95            25.0
# 107           31.0
# 84            27.0
# 98            30.0
# 136            2.0
# 125            1.0
# 130            3.0
# 131            8.0
# 126            4.0
# 123            5.0
# 119            9.0
# 143            6.0
# 142           15.0
# 141            7.0
# 137           16.0
# 135           11.0
# 132           10.0
# 145           14.0
# 144           20.0
# 117           12.0
# 115           22.0
# 114           30.0
# 139           21.0
# 134           19.0
# 118           24.0
# 127           13.0
# 128           33.0
# 133           31.0
# 129           27.0
# 120           32.0
# 124           25.0
# 116           17.0
# 122           26.0
# 112           29.0
# 113           28.0
# 140           23.0
# 121           18.0
# 138           34.0
# 149           14.0
# 152            1.0
# 159            3.0
# 163            2.0
# 169            4.0
# 167           10.0
# 170           27.0
# 153            6.0
# 171           16.0
# 151           18.0
# 156            5.0
# 158           26.0
# 175           13.0
# 174           31.0
# 160           15.0
# 166           25.0
# 164           23.0
# 176            8.0
# 168           28.0
# 155           12.0
# 173           30.0
# 146           19.0
# 150           24.0
# 147           21.0
# 165           11.0
# 161            9.0
# 172           17.0
# 148           29.0
# 162            7.0
# 154           20.0
# 157           22.0
# 182            4.0
# 183            2.0
# 184            1.0
# 181            3.0
# 177            5.0
# 179            6.0
# 178            8.0
# 185            9.0
# 186            7.0
# 180           10.0
# 216            1.0
# 187            3.0
# 219            2.0
# 207            4.0
# 206            7.0
# 208            8.0
# 192            5.0
# 209            9.0
# 204           18.0
# 215            6.0
# 193           17.0
# 191           25.0
# 195           26.0

# %%
training_predictions.to_csv('./data/hotelsearch_training_predictions.csv')
test_predictions.to_csv('./data/hotelsearch_test_predictions.csv')
